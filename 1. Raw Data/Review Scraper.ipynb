# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup
import time

import pandas as pd

# %%
chromedriver = "/Users/hoaha/Documents/chromedriver"
driver = webdriver.Chrome(chromedriver)
driver.get("https://booking.com")

time.sleep(2)
driver.find_element_by_css_selector("input[class*='sb-searchbox__input']").send_keys("Britannia International Hotel Canary Wharf")
driver.find_element_by_css_selector("button[type='submit']").click()
driver.find_element_by_xpath("//span[contains(text(),'Britannia International Hotel Canary Wharf')]").click()
driver.switch_to.window(driver.window_handles[1])
time.sleep(3)
driver.find_element_by_css_selector('#show_reviews_tab').click() 

driver.switch_to.window(driver.window_handles[1])

Name = []
Country = []
Room_stayed = []
Date_stayed = []
Trip_type = []
Review_date = []
Review_title = []
Positive = []
Negative = []
Reviewer_score =[]

while True:
    room_info_eles = WebDriverWait(driver, 20).until(EC.visibility_of_all_elements_located((By.CSS_SELECTOR, "div[itemprop='review']")))
    for element in room_info_eles:
        try:
            Name.append(element.find_element_by_class_name('bui-avatar-block__title').text)
        except:
            Name.append("Not Available")
            
        try:
            Country.append(element.find_element_by_class_name('bui-avatar-block__subtitle').text)
        except:
            Country.append("Not Available")
            
        try:
            Room_stayed.append(element.find_elements_by_class_name("bui-list__body")[0].text)
        except:
            Room_stayed.append("Not Available")
            
        try:
            Date_stayed.append(element.find_elements_by_class_name("bui-list__body")[1].text)
        except:
            Date_stayed.append("Not Available")
        
        try:
            Trip_type.append(element.find_elements_by_class_name("bui-list__body")[2].text)
        except:
            Trip_type.append("Not Available")
        
        try:
            Review_date.append(element.find_elements_by_class_name("c-review-block__date")[1].text)
        except:
            Review_date.append("Not Available")
        
        try:
            Review_title.append(element.find_elements_by_class_name("bui-grid__column-10")[0].text)
        except:
            Review_title.append("Not Available")
        
        try:
            Positive.append(element.find_elements_by_class_name("c-review__body")[0].text)
        except:
            Positive.append("Not Available")
        
        try:
            Negative.append(element.find_elements_by_class_name("c-review__body")[1].text)
        except:
            Negative.append("Not Available")
        
        try:
            Reviewer_score.append(element.find_elements_by_class_name("bui-review-score__badge")[0].text)
        except:
            Reviewer_score.append("Not Available")
        
    try:
        WebDriverWait(driver, 25).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "a[class='pagenext']"))).click()
    except Exception: 
        break

# %%
df = pd.DataFrame({"Name":Name,
                   "Country":Country,
                  "Room_stayed":Room_stayed,
                  "Date_stayed":Date_stayed,
                  "Trip_type":Trip_type,
                  "Review_date":Review_date,
                  "Review_title":Review_title,
                  "Positive":Positive,
                  "Negative":Negative,
                  "Reviewer_score":Reviewer_score})

# %%
df.head(50)
# Out:
#             Name         Country                          Room_stayed  \
# 0   Anuj          India           Standard Double Room without Window
# 1   B             United Kingdom  Standard Double Room
# 2   Lex           United Kingdom  Standard Double Room
# 3   Rashida       United Kingdom  Standard Twin Room
# 4   Floyd         United Kingdom  Standard Double Room
# 5   David         United Kingdom  Standard Double Room without Window
# 6   Antony        United Kingdom  Standard Double Room
# 7   Suresh        United Kingdom  Standard Double Room without Window
# 8   Freddie       Spain           Standard Twin Room without Window
# 9   Starboy       United Kingdom  Standard Double Room without Window
# 10  Taz           United Kingdom  Standard Double Room

#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Negative  \
# 0   There was cig box in the room which i think they forgot to clean.
# 1   Dirty windows and dead bug found in the bath also the heating was not working
# 2   Not Available
# 3   The first room given was not clean. On notifying the staff they changed our room straight away.
# 4   Not Available
# 5   Not Available
# 6   Sadly due to Covid restrictions as with all Hotels nothing was open.
# 7   WiFi not working .
# 8   The common areas are looking jaded and in need of redecorating. Grafitti scratched on lift. The car park was expensive.
# 9   TV had no working channels due to expose cable wire from connector which I had to push in. TV remote is useless in room 925. I don't know about other rooms. Fashion is low. For location I was really expecting something more worthy. Set the heating to 26° but all night I been shivering until I turned it off. I wish I could get back my money. I'd feel better sleeping in the car for the night. I've been to lower class hotels before but atleast they had usb plug sockets, here there was none. Its nothing compared to the images. And that car park really need some work done. I had to pay £20+ to park under that broken looking space. You get 2x20 minutes free on WiFi then you have to pay. Not the cleanest. Carpets are old and obvious.
# 10  Ok
# 11  Not Available
# 12  Only two channel in TV and the drainer filter AC must be clean.......
# 13  Not Available
# 14  My impression is that standar of everthing is a little bi aged and old...
# 15  Not Available
# 16  Not Available
# 17  Not Available
# 18  Not Available
# 19  Had to show photo ID, this was not made clear before arrival
# 20  Check out was at 10:00 instead of the usual 11:00 or even 12:00 at most other hotels and late check out was charged at a costly £10 per hour.
# 21  I think they should incorporate parking charges in the stay rather then charging on top. £25 for the day is a bit expensive especially as the parking facilities are on their site so they should accommodate for their guests
# 22  Not Available
# 23  Bathroom
# ...
# 30  No more spa
# 31  None
# 32  The bathroom door have a trouble to open ,\nI locked twice inside 🤩 but was everything nice and comfortable,\nThanks 😊
# 33  Stayed hear several times due to great location and price, but hotel starting to look dated and tired
# 34  The first room we where offered was poor but it was only £40 so we upgraded instantly and the new room was amazing. Word of advice, pay the extra to upgrade, the chesp rooms are cheap for a reason! Besides that it was excellent 👌
# 35  No wifi
# 36  That there was no window
# 37  Bed was a little uncomfortable but otherwise good stay
# 38  Didint like the early check out
# 39  Just the WiFi situation. Only if I didn't have unlimited data.
# 40  Not Available
# 41  Not Available
# 42  Great location
# 43  The beds were really bad 2 single mattress joined together kept falling in the crack
# 44  Bit dated
# 45  Nothing but Covid restrictions are frustrating - reduced elevators for example
# 46  Paying for parking
# 47  Bed was too uncomfortable
# 48  Not Available
# 49  Not Available
#
#    Reviewer_score
# 0   10
# 1   7.0
# 2   7.0
# 3   7.0
# 4   6.0
# 5   8.0
# 6   7.0
# 7   7.0
# 8   6.0
# 9   5.4
# 10  8.0
# 11  8.0
# 12  7.0
# 13  8.0
# 14  6.0
# 15  8.0
# 16  7.0
# 17  7.0
# 18  6.0
# 19  7.0
# 20  8.0
# 21  7.0
# 22  6.0
# 23  6.0
# 24  6.0
# 25  8.0
# 26  8.0
# 27  7.0
# 28  8.0
# 29  7.0
# 30  7.0
# 31  8.0
# 32  8.0
# 33  8.0
# 34  8.0
# 35  7.0
# 36  8.0
# 37  7.0
# 38  6.0
# 39  7.0
# 40  6.0
# 41  8.0
# 42  7.0
# 43  7.0
# 44  7.0
# 45  7.0
# 46  6.0
# 47  8.0
# 48  7.0
# 49  8.0

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-16-0891b765a168>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df.loc[df['Name']=="Meng"]
# Out:
#       Name Country           Room_stayed           Date_stayed      Trip_type  \
# 7326  Meng  Taiwan  Standard Double Room  1 night ·  June 2019  Solo traveler
#
#                   Review_date Review_title     Positive Negative  \
# 7326  Reviewed: June 23, 2019  Good         附近治安不錯，捷運站多
#
#      Reviewer_score
# 7326  7.9

# %%
df.to_csv('Britannia International Hotel Canary Wharf.csv', encoding='utf-8')
